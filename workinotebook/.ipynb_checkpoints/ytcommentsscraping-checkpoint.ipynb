# %% [markdown]
# Initializing

# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (2.198.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-python-client) (0.32.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-python-client) (2.55.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-python-client) (0.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-python-client) (2.31.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=5.29.6 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (7.35.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.24.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.28.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.33.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (49.0.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.4.22)
# Requirement already satisfied: cffi>=2.0.0 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/linuxsmol/projects/pythons/productsentiment/venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.3)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from googleapiclient.discovery import build
import pandas as pd

API_KEY = "AIzaSyAeO5ttPSQomlsQypdnCtMbcroxo3JN898"
VIDEO_ID = input("Masukkan ID Video")

youtube = build("youtube", "v3", developerKey=API_KEY)

def get_all_comments(video_id):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet,replies",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText"
    )

    while request:
        response = request.execute()
        for item in response["items"]:
            # Ambil komentar top level
            top = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "author": top.get("authorDisplayName"),
                "comment": top.get("textDisplay"),
                "publishedAt": top.get("publishedAt"),
                "likeCount": top.get("likeCount"),
            })
            # Ambil reply kalau ada
            if item["snippet"].get("totalReplyCount", 0) > 0:
                for reply in item["replies"]["comments"]:
                    r = reply["snippet"]
                    comments.append({
                        "author": r.get("authorDisplayName"),
                        "comment": r.get("textDisplay"),
                        "publishedAt": r.get("publishedAt"),
                        "likeCount": r.get("likeCount"),
                    })
        # lanjut ke halaman berikutnya
        request = youtube.commentThreads().list_next(request, response)
    
    return pd.DataFrame(comments)

df = get_all_comments(VIDEO_ID)
print(f"Jumlah komentar yang berhasil diambil: {len(df)}")
df.head()
# Out:
# Masukkan ID Video wr2NRceZgrA
# Jumlah komentar yang berhasil diambil: 1263
#           author                                            comment  \
# 0  @didi_sdi5343  kenapa punua sayah slot sim nya d pinggir kiri...
# 1   @ndnaudio138  Pa Bos Samsung suruh ngeluarin Seri M lagih Ja...
# 2     @elina7248  yang pake A56, layar kalian cenderung ijo/warm...
# 3    @Abay_akbar               Dari samaung A5 2017 ke samsung A56😂
# 4  @abdulmuin731                            Speaker outputnya yahud
#
#             publishedAt  likeCount
# 0  2026-06-28T08:37:50Z          0
# 1  2026-06-25T12:39:48Z          0
# 2  2026-05-31T10:51:06Z          0
# 3  2026-05-08T03:05:23Z          0
# 4  2026-05-03T04:41:36Z          0

# %%
from datetime import datetime

# Minta nama file dari user
nama_file = input("Masukkan nama file (tanpa ekstensi): ").strip()

# Ambil tanggal & waktu sekarang
timestamp = datetime.now().strftime("%d%m%Y_%I%M%S_%p")

# Gabungkan nama file + timestamp + ekstensi
final_filename = f"{nama_file}_{timestamp}.csv"

# Path penyimpanan
path = f"../data/raw/{final_filename}"

# Simpan ke CSV
df.to_csv(path, index=False)

print(f"Komentar berhasil disimpan di {path}")
# Out:
# Masukkan nama file (tanpa ekstensi):  a56samsung_jagatreview
# Komentar berhasil disimpan di ../data/raw/a56samsung_jagatreview_30062026_045904_PM.csv
